# %%
#Import Libaries
import json
import csv
import tweepy
import re
import pandas as pd

# %%
####input your credentials here
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
#Extract tweets with the hashtag #Sex4Grades
msgs = []
msg =[]

for tweet in tweepy.Cursor(api.search, q='#Sex4Grades', rpp=100).items(4000):
    msg = [tweet.created_at, tweet.text, tweet.lang, tweet.user.location, tweet.user.verified, tweet.source, tweet.retweet_count, tweet.favorite_count] 
    msg = tuple(msg)                    
    msgs.append(msg)

df = pd.DataFrame(msgs)

# %%
df.head(5)
# Out:
#                     0                                                  1   2  \
# 0 2019-10-09 17:32:34  Buhari fight corruption but don't fight #Sex4G...  en
# 1 2019-10-09 17:26:31  Lord forgive me but any man intro himself to m...  en
# 2 2019-10-09 17:14:34  RT @Letitoutgh: It’s typical of @UnivofGh lect...  en
# 3 2019-10-09 17:09:11  Biko nu ,who is the minister of education?\n#s...  en
# 4 2019-10-09 17:04:18  @emekachukwuleta Like I said, before.. @BBCAfr...  en
#
#                 3      4                    5   6  7
# 0         Nigeria  False  Twitter for Android   0  0
# 1         Nigeria  False  Twitter for Android   0  0
# 2                  False     Twitter for iPad  78  0
# 3  Lagos, Nigeria  False  Twitter for Android   0  0
# 4  Lagos, Nigeria  False  Twitter for Android   0  0

# %%
#Extract tweets with the hashtag #BBCAfricaEyes
msgs = []
msg =[]

for tweet in tweepy.Cursor(api.search, q='#BBCAfricaEyes', rpp=100).items(4000):
    msg = [tweet.created_at, tweet.text, tweet.lang, tweet.user.location, tweet.user.verified, tweet.source, tweet.retweet_count, tweet.favorite_count] 
    msg = tuple(msg)                    
    msgs.append(msg)

BBCAfricaEye = pd.DataFrame(msgs)

# %%
BBCAfricaEye
# Out:
#                     0                                                  1   2  \
# 0 2019-10-08 11:19:20  RT @BoombuzzNG: The Unilag lecturer, Dr Bonifa...  en
# 1 2019-10-08 11:17:43  The Unilag lecturer, Dr Boniface Igbenehue rep...  en
# 2 2019-10-07 10:33:58  I love this country they really know how to ke...  en
# 3 2019-10-07 09:35:28  #Mondaymotivation\n\nTo Improve your business ...  en
# 4 2019-10-07 09:30:30  #Mondaymotivation\n\nTo Improve your business ...  en
# 5 2019-10-07 09:28:59  #Mondaymotivation\n\nTo Improve your business ...  en
# 6 2019-10-07 09:25:56  #Mondaymotivation\n\nTo Improve your business ...  en
#
#          3      4                    5  6  7
# 0           False   Twitter for iPhone  2  0
# 1  Nigeria  False   Twitter for iPhone  2  1
# 2    ABUJA  False  Twitter for Android  0  1
# 3  Nigeria  False       Hootsuite Inc.  0  0
# 4  Nigeria  False       Hootsuite Inc.  0  0
# 5  Nigeria  False       Hootsuite Inc.  0  0
# 6    Lagos  False       Hootsuite Inc.  0  1

# %%
#export data to csv
df.to_csv("Sex4Grades.csv", index=False)

# %%
BBCAfricaEye.to_csv("BBCAfricaEye.csv", index=False)
