# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('BBCAfricaEye.csv')

# %%
df.head()
# Out:
#       tweet.created_at                                         tweet.text  \
# 0  2019-10-11 09:17:01  RT @kikimordi: Hey I forgot to mention that we...
# 1  2019-10-11 09:16:31  RT @TheAfricaReport: For Nigeria in particular...
# 2  2019-10-11 09:15:08  RT @BBCAfrica: "This was the hardest thing I'v...
# 3  2019-10-11 09:12:44  RT @TraQman: Locking up the ‘cold room’ is not...
# 4  2019-10-11 09:11:43  RT @BBCAfrica: For the past year, BBC Africa E...
#
#   tweet.lang tweet.user.location  tweet.user.verified         tweet.source  \
# 0         en                 NaN                False  Twitter for Android
# 1         en      Abuja, Nigeria                False   Twitter for iPhone
# 2         en       Lagos Nigeria                False  Twitter for Android
# 3         en                 NaN                False   Twitter for iPhone
# 4         en               Kano                 False     Twitter for iPad
#
#    tweet.retweet_count  tweet.favorite_count
# ...

# %%
df.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']

# %%
df2 = pd.read_csv('ColdRoom.csv')

# %%
df2.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']

# %%
df2.head()
# Out:
#       tweet.created_at                                         tweet.text  \
# 0  2019-10-11 13:23:37  RT @Nwankpa_A: Not until there's a comprehensi...
# 1  2019-10-11 13:16:27  RT @gidifeedtv: #SexForGrades #Coldroom https:...
# 2  2019-10-11 13:16:23  RT @gidifeedtv: #SexforGrades #Coldroom https:...
# 3  2019-10-11 13:16:09  RT @gidifeedtv: #SexforGrades #Coldroom  cc @G...
# 4  2019-10-11 13:00:25  Nigerian Senate Reintroduces Anti-Sexual Haras...
#
#   tweet.lang tweet.user.location  tweet.user.verified         tweet.source  \
# 0         en           Graceland                False   Twitter for iPhone
# 1        und             OUTSIDE                False  Twitter for Android
# 2        und             OUTSIDE                False  Twitter for Android
# 3        und             OUTSIDE                False  Twitter for Android
# 4         en              Africa                 True        allAfrica.com
#
#    tweet.retweet_count  tweet.favorite_count
# ...

# %%
df3 = pd.read_csv('DrBoniface.csv')

# %%
df3.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']

# %%
df3.head()
# Out:
#       tweet.created_at                                         tweet.text  \
# 0  2019-10-11 10:37:50  RT @Qweku_Jay: When the students refuse to ent...
# 1  2019-10-11 08:09:44  RT @TWmagazineNG: Has another #UniLag lecturer...
# 2  2019-10-11 07:50:52  Has another #UniLag lecturer joined #DrBonifac...
# 3  2019-10-11 05:57:53  RT @ekekan12332: WOW I CAN'T BELIEVE I WON AGA...
# 4  2019-10-10 20:16:21  RT @therealveev: VERY CLEAN CAR FOR SALE\r\n20...
#
#   tweet.lang tweet.user.location  tweet.user.verified         tweet.source  \
# 0         en       Tamale, Ghana                False   Twitter for iPhone
# 1         en                 NaN                False  Twitter for Android
# 2         en      Lagos, Nigeria                False   Twitter for iPhone
# 3         en                 NaN                False  Twitter for Android
# 4         en      Lagos, Nigeria                False  Twitter for Android
#
#    tweet.retweet_count  tweet.favorite_count
# ...

# %%
df4 = pd.read_csv('Gyampo.csv')

# %%
df4.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']

# %%
df5 = pd.read_csv('Sex4Grades.csv')
df6 = pd.read_csv('SexForGrades.csv')
df7 = pd.read_csv('Unilag.csv')

# %%
df5.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']
df6.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']
df7.columns = ['tweet.created_at', 'tweet.text', 'tweet.lang', 'tweet.user.location', 'tweet.user.verified', 
              'tweet.source' , 'tweet.retweet_count','tweet.favorite_count']

# %%
df7.head()
# Out:
#       tweet.created_at                                         tweet.text  \
# 0  2019-10-11 13:22:18  RT @micheal__og: Come join me tomorrow as I sp...
# 1  2019-10-11 13:12:46  RT @pweetychemmie: Please retweet my customers...
# 2  2019-10-11 13:06:37  RT @micheal__og: Come join me tomorrow as I sp...
# 3  2019-10-11 12:28:17  RT @Mosmikey: We should not laugh.\r\nWe shoul...
# 4  2019-10-11 12:24:27  RT @Mosmikey: We should not laugh.\r\nWe shoul...
#
#   tweet.lang   tweet.user.location  tweet.user.verified         tweet.source  \
# 0         en                   NaN                False   Twitter for iPhone
# 1         en      Ilishan, Nigeria                False      Twitter Web App
# 2         en               Nigeria                False  Twitter for Android
# 3         en           Tema, Ghana                False  Twitter for Android
# 4         en  Greater Accra, Ghana                False   Twitter for iPhone
#
#    tweet.retweet_count  tweet.favorite_count
# ...
